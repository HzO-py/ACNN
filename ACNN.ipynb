# %%
from tqdm import tqdm
from preprocess import process_subject
abnormal_subjects=[]
for i in tqdm(range(1,181)):
    process_subject(i,abnormal_subjects)
# print(f"Total: {len(abnormal_subjects)} subjects with abnormal channels")
# cnt=0
# for sid, count in abnormal_subjects:
#     if count==4:
#         print(f"Subject {sid}: {count} abnormal channel(s)")
#         cnt+=1
# print(cnt)
# Out:
#  50%|█████     | 90/180 [00:02<00:01, 45.85it/s]
# Subject 83: SBP/DBP out of ±3σ range, skipped.
#  56%|█████▌    | 101/180 [00:02<00:01, 46.80it/s]
# Subject 93: SBP/DBP out of ±3σ range, skipped.
# 100%|██████████| 180/180 [00:04<00:00, 43.85it/s]
# Subject 174: SBP/DBP out of ±3σ range, skipped.

# %%
from preprocess import process_subject
# for i in range(1,181):
#     process_subject(i)
process_subject(21)
process_subject(26)
process_subject(27)
# Out:
# (12000, 4)
# (12000, 4)
# (12000, 4)
# (12000, 4)
# (12000, 4)
# (12000, 4)
# {'id': 27, 'sbp': 112.0, 'dbp': 76.6666666666667}
